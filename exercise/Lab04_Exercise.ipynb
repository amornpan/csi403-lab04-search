# %% [markdown]
# # Lab 04: Text Search - Exercise
#
# **Total Points:** 100 | **Time:** ~45 minutes
#
# ---

# %% [markdown]
# ## Exercise 1: Check Text Exists (25 pts)
#
# Create `has_fever` variable that is `True` if 'fever' is in the text (case-insensitive).

# %%
text = 'Rubella causes high FEVER and skin rash'

# YOUR CODE HERE
has_fever = None

# Check your answer
print(f'Has fever: {has_fever}')

# %%
# Quick check (structure only)
if has_fever is not None:
    print(f'✅ has_fever has a value')
    if isinstance(has_fever, bool):
        print(f'✅ has_fever is a boolean')
    else:
        print(f'❌ has_fever should be a boolean (True/False)')
else:
    print('❌ has_fever is still None')

# %% [markdown]
# ---
#
# ## Exercise 2: Count Occurrences (25 pts)
#
# Count how many times 'the' appears (case-insensitive). Store in `the_count`.

# %%
text = 'The disease spreads through the air. The treatment is rest.'

# YOUR CODE HERE
the_count = None

# Check your answer
print(f'Count: {the_count}')

# %%
# Quick check (structure only)
if the_count is not None:
    print(f'✅ the_count has a value')
    if isinstance(the_count, int):
        print(f'✅ the_count is an integer')
    else:
        print(f'❌ the_count should be an integer')
else:
    print('❌ the_count is still None')

# %% [markdown]
# ---
#
# ## Exercise 3: Search Function (25 pts)
#
# Create `simple_search(query, text)` that returns `True` if query found (case-insensitive).

# %%
# YOUR CODE HERE
def simple_search(query, text):
    pass  # Replace with your code

# Check your answer
print(f"Test 1: {simple_search('fever', 'Patient has FEVER')}")
print(f"Test 2: {simple_search('cough', 'Patient has fever')}")

# %%
# Quick check (structure only)
result = simple_search('test', 'This is a TEST')
if result is not None:
    print(f'✅ Function returns a value')
    if isinstance(result, bool):
        print(f'✅ Function returns a boolean')
    else:
        print(f'❌ Function should return a boolean')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## Exercise 4: Multi-Document Search (25 pts)
#
# Create `search_docs(query, docs)` that returns a list of documents containing the query.

# %%
documents = [
    'Rubella causes fever and rash',
    'Cholera causes severe diarrhea',
    'Dengue causes high fever',
    'GERD causes heartburn'
]

# YOUR CODE HERE
def search_docs(query, docs):
    pass  # Replace with your code

# Check your answer
result = search_docs('fever', documents)
print(f'Found: {result}')

# %%
# Quick check (structure only)
result = search_docs('fever', documents)
if result is not None:
    print(f'✅ Function returns a value')
    if isinstance(result, list):
        print(f'✅ Function returns a list')
        print(f'   Number of matches: {len(result)}')
    else:
        print(f'❌ Function should return a list')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## 🎉 Finished!
#
# ### Summary:
# | Exercise | Skill |
# |----------|-------|
# | 1 | Check if text exists |
# | 2 | Count occurrences |
# | 3 | Create search function |
# | 4 | Search multiple documents |
#
# ### Submit:
# ```bash
# git add . && git commit -m 'Complete Lab 04' && git push
# ```
#
# Check your score in GitHub Actions tab!
